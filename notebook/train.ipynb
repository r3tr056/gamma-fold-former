# %% [markdown]
# # GammaFold Former Protein Transformer
# This notebook builds a protein dataset from UniProt and trains a state-of-the-art transformer model.

# %%
# Install Required Packages
# %pip install biopython requests torch

# %%
import os
import logging
from datetime import datetime

config = {
    "uniprot_query": "(reviewed:true) AND (organism_id:9606)",
    "target_count": 500000,  # Target number of sequences
    "local_files": [],  # Add any local FASTA files here
    "output_file": "./tmp/protein_dataset.fasta",
    "min_length": 50,
    "max_length_filter": 1000,
    
    # Training parameters
    "batch_size": 128,
    "max_length": 512,
    "vocab_size": 24,
    "embed_dim": 512,
    "num_heads": 16,
    "num_layers": 12,
    "dropout": 0.1,
    "num_epochs": 50,
    "learning_rate": 5e-4,
    "warmup_steps": 10000,
    
    # System config
    "checkpoint_dir": "./tmp/gammafold_checkpoints",
    "log_dir": "./tmp/gammafold_logs"
}

# create directories
os.makedirs(config['checkpoint_dir'], exist_ok=True)
os.makedirs(config['log_dir'], exist_ok=True)

# Setup logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s %(levelname)s: %(message)s',
    handlers=[
        logging.FileHandler(os.path.join(config["log_dir"], "gammafold.log")),
        logging.StreamHandler()
    ]
)

# %%
from gammaf.cli import build_dataset_from_uniprot

# Build dataset
logging.info
